# %% [markdown]
# ## Lab: Cart Pole using OpenAI gym
# ## RL Basics and Simple Policy
#
# ### University of Virginia
# ### Reinforcement Learning
# #### Last updated: September 18, 2026
#
# ---

# %% [markdown]
# #### Instructions:
#
# Carefully read the notes below and run the provided code. Answer each question clearly and show all results.
#
# **Guidelines on AI tools:**
#
# All code should be your own. If you would like to get help from an LLM, you may use it as a tutor or coding assistant to explain concepts, help you debug, suggest approaches, or provide small examples. You should understand, review, and test any code that you use, and you should be able to explain how your submitted code works. Do not use an LLM to generate the entire solution and submit it without substantial review and understanding.
#
#
# #### TOTAL POINTS: 12
#
# ---

# %% [markdown]
# ### Agent and Environment
#
# It is essential for the agent to have a way to get the next state and reward from the environment.
#
# Sometimes it is possible for the agent to interact with environment in real life, but often this is expensive / dangerous / impossible.
#
# We use models and simulators in this latter case.
#
# For this reason, the Gym package is useful in RL
#
# **Note**: Going forward, the fork [gymnasium](https://gymnasium.farama.org/) will maintain OpenAI gym.
# We will be using `gymnasium` but will still refer to the environment as `gym` when it doesn't cause confusion.
#
# ---

# %% [markdown]
# ### Introduction to Gym
#
# Gym is a toolkit for developing and comparing RL algorithms.
#
# It comes with many pre-built environments which have functionality to emulate physical environments.
#
#
# ---

# %% [markdown]
# ### Cart Pole Problem
#
# The **CartPole** problem has a small state space and action space, so it's popular for illustrating ideas.
#
# The pole is attached to a cart on a frictionless track.
#
# The pole starts upright
#
# **Goal** is to keep pole from falling over
#
# Control system by applying **force** -1 or +1 to cart.
#
# **Reward** of +1 for each timestep the pole remains upright
#
# **Episode** ends when pole is more than 12 degrees from vertical, or cart moves more than 2.4 units from center.
# **We will call this going "off track."**
#
# CartPole-v1 defines *solving* as getting average reward of 195.0 over 100 consecutive trials.

# %% [markdown]
# <img src="./cartpole.png" alt="drawing" width="150"/>

# %% [markdown]
# ---

# %% [markdown]
# ### Setup and First Steps

# %% [markdown]
# This notebook can be easily run on [Google Colab](https://colab.research.google.com/)

# %%
! pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.13/dist-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.13/dist-packages (from gymnasium) (2.1.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.13/dist-packages (from gymnasium) (4.16.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.13/dist-packages (from gymnasium) (0.0.6)

# %% [markdown]
# We can use [renderlab](https://github.com/ryanrudes/renderlab/tree/main) to visualize *results*

# %%
! pip install renderlab
# Out:
# Collecting renderlab
#   Downloading renderlab-0.1.20230421184216.post1-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.13/dist-packages (from renderlab) (1.0.3)
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.13/dist-packages (from renderlab) (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.13/dist-packages (from gymnasium->renderlab) (2.1.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from gymnasium->renderlab) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.13/dist-packages (from gymnasium->renderlab) (4.16.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.13/dist-packages (from gymnasium->renderlab) (0.0.6)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.13/dist-packages (from moviepy->renderlab) (4.4.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.13/dist-packages (from moviepy->renderlab) (2.37.4)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from moviepy->renderlab) (0.6.0)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.13/dist-packages (from moviepy->renderlab) (4.67.3)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.13/dist-packages (from moviepy->renderlab) (2.32.4)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.13/dist-packages (from moviepy->renderlab) (0.1.12)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.13/dist-packages (from imageio<3.0,>=2.5->moviepy->renderlab) (11.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0,>=2.8.1->moviepy->renderlab) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3.0,>=2.8.1->moviepy->renderlab) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3.0,>=2.8.1->moviepy->renderlab) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests<3.0,>=2.8.1->moviepy->renderlab) (2026.7.22)
# Downloading renderlab-0.1.20230421184216.post1-py3-none-any.whl (4.0 kB)
# Installing collected packages: renderlab
# Successfully installed renderlab-0.1.20230421184216.post1

# %%
import gymnasium as gym
import renderlab as rl
# Out:
# /usr/local/lib/python3.13/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# /usr/local/lib/python3.13/dist-packages/moviepy/video/io/ffmpeg_reader.py:294: SyntaxWarning: invalid escape sequence '\d'
#   lines_video = [l for l in lines if ' Video: ' in l and re.search('\d+x\d+', l)]
# /usr/local/lib/python3.13/dist-packages/moviepy/video/io/ffmpeg_reader.py:367: SyntaxWarning: invalid escape sequence '\d'
#   rotation_lines = [l for l in lines if 'rotate          :' in l and re.search('\d+$', l)]
# /usr/local/lib/python3.13/dist-packages/moviepy/video/io/ffmpeg_reader.py:370: SyntaxWarning: invalid escape sequence '\d'
#   match = re.search('\d+$', rotation_line)
# WARNING:py.warnings:/usr/local/lib/python3.13/dist-packages/moviepy/video/io/sliders.py:61: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   if event.key is 'enter':
#
# WARNING:py.warnings:/usr/local/lib/python3.13/dist-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %% [markdown]
# Load the environment

# %%
env = gym.make("CartPole-v1", render_mode = "rgb_array")

state = env.reset(seed=314)
print(state)
# Out:
# (array([0.04225422, 0.02126478, 0.02520455, 0.00700802], dtype=float32), {})

# %% [markdown]
# Given the state, we take an action. The next state comes from the environment, which is encoded in `gym`.
#
# The first element holds components:
# [0]: cart horizontal position (0.0 = center)
# [1]: velocity (positive means right)
# [2]: angle of the pole (0.0 = vertical)
# [3]: pole's angular velocity (positive means clockwise)

# %%
# state space number of components
env.observation_space.shape[0]
# Out:
# 4

# %% [markdown]
# The action space consists of two options:
#
# [0]: move cart left
# [1]: move cart right

# %%
env.action_space
# Out:
# Discrete(2)

# %% [markdown]
# Let's take an action, draw a sample and look at the results.

# %%
# move right
action = 1

# take a step and get next state, reward from environment
state, reward, terminated, truncated, info = env.step(action)
done = terminated or truncated

print('state', state)
print('reward', reward)
print('done', done)
print('info', info)
# Out:
# state [ 0.04699984  0.41076773  0.01979236 -0.56219995]
# reward 1.0
# done False
# info {}

# %% [markdown]
# **Note about DONE**
# We need to understand if the episode is done after taking action
#
# The API now gives more detail on this variable, which may reach `done` state for two reasons:
# - **terminated**=True if environment terminates (eg. due to task completion, failure etc.)
# - **truncated**=True if episode truncates due to a time limit or a reason that is not defined as part of the task MDP.

# %% [markdown]
# **Run several steps by taking random actions**

# %%
state = env.reset(seed=314)
for _ in range(5):
    print(env.step(env.action_space.sample())) # take a random action
# Out:
# (array([ 0.04267951, -0.1742094 ,  0.02534471,  0.30753553], dtype=float32), 1.0, False, False, {})
# (array([0.03919533, 0.02054241, 0.03149542, 0.02295217], dtype=float32), 1.0, False, False, {})
# (array([ 0.03960617, -0.17501673,  0.03195446,  0.3254035 ], dtype=float32), 1.0, False, False, {})
# (array([ 0.03610584, -0.37057874,  0.03846253,  0.62798977], dtype=float32), 1.0, False, False, {})
# (array([ 0.02869426, -0.5662158 ,  0.05102233,  0.9325335 ], dtype=float32), 1.0, False, False, {})

# %% [markdown]
# **Run an epoch by taking random actions. Visualize the results.**

# %%
env = rl.RenderFrame(env, "./output")

observation, info = env.reset()

while True:
    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)

    if terminated or truncated:
      break

env.play()
# Out:
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# **Reward and Episode**
#
# For each time step that the cart keeps the pole balanced, it earns reward 1.
#
# If the pole tilts too much or if the cart moves off screen, `reward=0` and `done=True` (the episode will end).
#
# When the episode ends, a new episode may begin. The process learns cumulatively from each episode.
#
# ---

# %% [markdown]
# #### 1) Defining a function that runs a simple policy
# **(POINTS: 2)**
#
# When the pole leans left (negative angle), move left. When the pole leans right (positive angle), move right.
#
# The function should take the state and return an action. Test that it works properly.

# %% [markdown]
# #### 2) Simulating episodes with the simple policy
#
# 2a) **(POINTS: 2)** Run 1000 episodes each with 1000 time steps. Use the `simple_policy` for taking actions.
# Each time step will call the `step()` method to get the next state and reward. Produce a boxplot of the rewards from each episode.

# %% [markdown]
# 2b) **(POINTS: 1)** Is this policy able to solve the cart pole problem? Explain your answer.

# %% [markdown]
# #### 3) From Question [2], what is the mean and maximum reward (roughly)?
# **(POINTS: 1)**

# %% [markdown]
# #### 4) Reversed Simple Policy
# **(POINTS: 2)**
#
# What happens if you reverse the simple policy, moving left when the pole leans right, and moving right when the pole leans left? This is not a good idea, but it's instructive. To show the result, produce the boxplot from before, and calculate the mean reward.

# %% [markdown]
# #### 5) Modified Policy
# **(POINTS: 2)** Full points for attempt and clear explanation.
#
# Time to get creative! See if you can try a different policy that improves the mean reward. Clearly explain your strategy.

# %% [markdown]
# #### 6) Going Off Track
#
# **(POINTS: 2)** We saw that one of the ways an episode ends is the cart moves too far from the center and goes off track. Write, test, and run code that shows evidence of this happening, printing the episode number and cart position when it happens.

# %% [markdown]
# ---
#
# ### Wrapup
#
# This demo illustrated some basic ideas of reinforcement learning and got you started with OpenAI Gym.
#
# We will revisit this example later, bringing in more tools for a better solution.
#
# ---
